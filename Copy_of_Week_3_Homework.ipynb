# %% [markdown]
# <a href="https://colab.research.google.com/github/laurasimpson18/Week4Warmup/blob/main/Copy_of_Week_3_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 3 Homework
#
# (Be sure to copy to drive first)
#
# For this homework we are going to apply some text analysis stuff to a collection of PDF file that I'll ask you to put together.

# %%
#Install / load our libraries and connect to Google Drive

# !pip install pypdf

#Colab has a special library just for working with files on google drive
from google.colab import drive


#This is a new library we'll use to extract text from PDFs
from pypdf import PdfReader


import textblob
import pandas as pd
import numpy as np
import glob

#Some extra libraries we'll need for text analysis
import nltk
nltk.download('punkt')
nltk.download('brown')
nltk.download('punkt_tab')

#Connect to Gdrive
drive.mount('/content/gdrive')

print("Libraries and Drive Ready!")
# Out:
# Requirement already satisfied: pypdf in /usr/local/lib/python3.12/dist-packages (6.0.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Mounted at /content/gdrive
# Libraries and Drive Ready!

# %% [markdown]
# **H1**
#
#
# Part of the work for this week is going to be finding a collection of 6 or so PDFs. These PDFS ideally should be on the same thing (journal articles on the same topic). Additionally these PDFs whould be Open Access, or the very least obtained lawfully * ***ahem*** *.
#
# Copy these 6 PDFs into the `LibraryJuicePython` folder on Google Drive. We'll be peforming some text analysis on these files.

# %%
#Run this cell to see the files in your directory
for file in glob.glob("/content/gdrive/MyDrive/LibraryJuicePython/*.pdf"):
  print(file)
# Out:
# /content/gdrive/MyDrive/LibraryJuicePython/fneur-14-1188037.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/Comprehensive_immune_profiling.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/Muscle and Nerve - 2020 - Kazamel - Metabolic syndrome and peripheral neuropathy.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/fneur-13-1004125.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/Hereditary_Sensory_and_Autonom.pdf
# /content/gdrive/MyDrive/LibraryJuicePython/Fat_mass_loss_correlates_with_.pdf

# %% [markdown]
# # Exracting the text from the PDFs
#
# We'll use a Python Library to create a text file of the contents of the PDF file.

# %%
for file in glob.glob("/content/gdrive/MyDrive/LibraryJuicePython/*.pdf"):
  filename = file.split("/")[-1]
  print("Extracting text for... ",filename)

  text = ""
  #This bit is new!
  reader = PdfReader(file)
  for page in reader.pages:
    text += page.extract_text()

  #Output the string variable into a text file
  output_text_file = filename+".txt"
  with open(output_text_file, "w") as text_file:
    text_file.write(text)
# Out:
# Extracting text for...  Muscle and Nerve - 2020 - Kazamel - Metabolic syndrome and peripheral neuropathy.pdf
# Extracting text for...  Hereditary_Sensory_and_Autonom.pdf
# Extracting text for...  fneur-13-1004125.pdf
# Extracting text for...  Fat_mass_loss_correlates_with_.pdf
# Extracting text for...  fneur-14-1188037.pdf
# Extracting text for...  Comprehensive_immune_profiling.pdf

# %% [markdown]
# # Sentiment of our PDFs
#
# Let's just print our sentiment scores to the screen for now.

# %%
for file in glob.glob("*.txt"):
  print("Sentiment for ",file)
  with open(file,"r") as text_file:
    text = text_file.read()
    blob = textblob.TextBlob(text)
    print(blob.sentiment)
    print("---")
# Out:
# Sentiment for  Muscle and Nerve - 2020 - Kazamel - Metabolic syndrome and peripheral neuropathy.pdf.txt
# Sentiment(polarity=0.06350312593186702, subjectivity=0.4339778254208187)
# ---
# Sentiment for  fneur-13-1004125.pdf.txt
# Sentiment(polarity=0.1811779730073847, subjectivity=0.5598716244539786)
# ---
# Sentiment for  Fat_mass_loss_correlates_with_.pdf.txt
# Sentiment(polarity=0.03800591847584327, subjectivity=0.47686029300690974)
# ---
# Sentiment for  Comprehensive_immune_profiling.pdf.txt
# Sentiment(polarity=0.08271917978776383, subjectivity=0.46587789238784816)
# ---
# Sentiment for  fneur-14-1188037.pdf.txt
# Sentiment(polarity=0.1373176748176748, subjectivity=0.4967932217932218)
# ---
# Sentiment for  Hereditary_Sensory_and_Autonom.pdf.txt
# Sentiment(polarity=0.06326850457989948, subjectivity=0.44217295801775236)
# ---

# %% [markdown]
# # Noun Phrases of our PDFs
#
# We'll just do the top 3 keywords of each file and display it to the screen

# %%
for file in glob.glob("*.txt"):
  print("Top 5 Phrases for ",file)
  with open(file,"r") as text_file:
    text = text_file.read()

  blob = textblob.TextBlob(text)
  nphrases = dict()

  for np in blob.noun_phrases:
    if np in nphrases:
         nphrases[np] += 1
    else:
         nphrases[np] = 1

  for np in sorted(nphrases, key=nphrases.get, reverse=True)[0:3]:
      print(np, nphrases[np])

  print("---")
# Out:
# Top 5 Phrases for  Muscle and Nerve - 2020 - Kazamel - Metabolic syndrome and peripheral neuropathy.pdf.txt
# mets 65
# cspn 29
# dpn 23
# ---
# Top 5 Phrases for  fneur-13-1004125.pdf.txt
# acute attacks 22
# chronic pain 17
# ala 17
# ---
# Top 5 Phrases for  Fat_mass_loss_correlates_with_.pdf.txt
# als 69
# pmid 33
# pd 31
# ---
# Top 5 Phrases for  Comprehensive_immune_profiling.pdf.txt
# als 137
# profile 63
# cd56 51
# ---
# Top 5 Phrases for  fneur-14-1188037.pdf.txt
# neuromuscular disorders 5
# genomic medicine 5
# neurology 5
# ---
# Top 5 Phrases for  Hereditary_Sensory_and_Autonom.pdf.txt
# familial dysautonomia 26
# axelrod fb 20
# hsan 14
# ---

# %% [markdown]
# # Dataframe of results
#
# Let's put our findings into a dataframe and save them to our drive. (We will use these PDFs again in our Week 4 work)

# %%
data_set = []

for file in glob.glob("*.txt"):

  pdf_detail = []

  with open(file,"r") as text_file:
    text = text_file.read()
  blob = textblob.TextBlob(text)

  print("working on ",file)
  pdf_detail.append(file)
  pdf_detail.append(blob.sentiment.polarity)
  pdf_detail.append(blob.sentiment.subjectivity)


  nphrases = dict()
  for np in blob.noun_phrases:
    if np in nphrases:
      nphrases[np] += 1
    else:
      nphrases[np] = 1

  #This is a weird way to find the top three keywords
  #This is an example of 'hacky' code

  #we loop through the first entry [0:1] in the sorted keyword list
  #giving us keyword one
  for np in sorted(nphrases, key=nphrases.get, reverse=True)[0:1]:
      keyword_one = np
      pdf_detail.append(keyword_one)

  #we loop through the first entry [1:2] in the sorted keyword list
  #giving us keyword two
  for np in sorted(nphrases, key=nphrases.get, reverse=True)[1:2]:
      keyword_two = np
      pdf_detail.append(keyword_two)

  #we loop through the first entry [2:3] in the sorted keyword list
  #giving us keyword two
  for np in sorted(nphrases, key=nphrases.get, reverse=True)[2:3]:
      keyword_three = np
      pdf_detail.append(keyword_three)

  data_set.append(pdf_detail)
  print(pdf_detail)
  print("---")
# Out:
# working on  Muscle and Nerve - 2020 - Kazamel - Metabolic syndrome and peripheral neuropathy.pdf.txt
# ['Muscle and Nerve - 2020 - Kazamel - Metabolic syndrome and peripheral neuropathy.pdf.txt', 0.06350312593186702, 0.4339778254208187, 'mets', 'cspn', 'dpn']
# ---
# working on  fneur-13-1004125.pdf.txt
# ['fneur-13-1004125.pdf.txt', 0.1811779730073847, 0.5598716244539786, 'acute attacks', 'chronic pain', 'ala']
# ---
# working on  Fat_mass_loss_correlates_with_.pdf.txt
# ['Fat_mass_loss_correlates_with_.pdf.txt', 0.03800591847584327, 0.47686029300690974, 'als', 'pmid', 'pd']
# ---
# working on  Comprehensive_immune_profiling.pdf.txt
# ['Comprehensive_immune_profiling.pdf.txt', 0.08271917978776383, 0.46587789238784816, 'als', 'profile', 'cd56']
# ---
# working on  fneur-14-1188037.pdf.txt
# ['fneur-14-1188037.pdf.txt', 0.1373176748176748, 0.4967932217932218, 'neuromuscular disorders', 'genomic medicine', 'neurology']
# ---
# working on  Hereditary_Sensory_and_Autonom.pdf.txt
# ['Hereditary_Sensory_and_Autonom.pdf.txt', 0.06326850457989948, 0.44217295801775236, 'familial dysautonomia', 'axelrod fb', 'hsan']
# ---

# %%
#We now have a list of lists
#This sorta looks like JSON doesn't it?
data_set
# Out:
# [['Muscle and Nerve - 2020 - Kazamel - Metabolic syndrome and peripheral neuropathy.pdf.txt',
#   0.06350312593186702,
#   0.4339778254208187,
#   'mets',
#   'cspn',
#   'dpn'],
#  ['fneur-13-1004125.pdf.txt',
#   0.1811779730073847,
#   0.5598716244539786,
#   'acute attacks',
#   'chronic pain',
#   'ala'],
#  ['Fat_mass_loss_correlates_with_.pdf.txt',
#   0.03800591847584327,
#   0.47686029300690974,
#   'als',
#   'pmid',
#   'pd'],
#  ['Comprehensive_immune_profiling.pdf.txt',
#   0.08271917978776383,
#   0.46587789238784816,
#   'als',
#   'profile',
#   'cd56'],
#  ['fneur-14-1188037.pdf.txt',
#   0.1373176748176748,
#   0.4967932217932218,
#   'neuromuscular disorders',
#   'genomic medicine',
#   'neurology'],
#  ['Hereditary_Sensory_and_Autonom.pdf.txt',
#   0.06326850457989948,
#   0.44217295801775236,
#   'familial dysautonomia',
#   'axelrod fb',
#   'hsan']]

# %%
#Let's turn this list of lists into a pandas dataframe
pdf_dataframe = pd.DataFrame(data_set)
pdf_dataframe
# Out:
#                                                    0         1         2  \
# 0  Muscle and Nerve - 2020 - Kazamel - Metabolic ...  0.063503  0.433978
# 1                           fneur-13-1004125.pdf.txt  0.181178  0.559872
# 2             Fat_mass_loss_correlates_with_.pdf.txt  0.038006  0.476860
# 3             Comprehensive_immune_profiling.pdf.txt  0.082719  0.465878
# 4                           fneur-14-1188037.pdf.txt  0.137318  0.496793
# 5             Hereditary_Sensory_and_Autonom.pdf.txt  0.063269  0.442173
#
#                          3                 4          5
# 0                     mets              cspn        dpn
# 1            acute attacks      chronic pain        ala
# 2                      als              pmid         pd
# 3                      als           profile       cd56
# 4  neuromuscular disorders  genomic medicine  neurology
# 5    familial dysautonomia        axelrod fb       hsan

# %% [markdown]
# **H2**
#
# Our dataframe needs better column names. Put the appropriate values into the list below on line 1 to update the column names.

# %%
column_names = ["title","polarity","subjectivity","keyword1","keyword2","keyword3"]
pdf_dataframe.columns = column_names
pdf_dataframe
# Out:
#                                                title  polarity  subjectivity  \
# 0  Muscle and Nerve - 2020 - Kazamel - Metabolic ...  0.063503      0.433978
# 1                           fneur-13-1004125.pdf.txt  0.181178      0.559872
# 2             Fat_mass_loss_correlates_with_.pdf.txt  0.038006      0.476860
# 3             Comprehensive_immune_profiling.pdf.txt  0.082719      0.465878
# 4                           fneur-14-1188037.pdf.txt  0.137318      0.496793
# 5             Hereditary_Sensory_and_Autonom.pdf.txt  0.063269      0.442173
#
#                   keyword1          keyword2   keyword3
# 0                     mets              cspn        dpn
# 1            acute attacks      chronic pain        ala
# 2                      als              pmid         pd
# 3                      als           profile       cd56
# 4  neuromuscular disorders  genomic medicine  neurology
# 5    familial dysautonomia        axelrod fb       hsan

# %% [markdown]
# # Save our data
#
# We'll save our dataframe as a CSV file and put it in our usual folder.

# %%
pdf_dataframe.to_csv("adv_week3_homework.csv", index=False)
# !cp adv_week3_homework.csv /content/gdrive/MyDrive/LibraryJuicePython

# %% [markdown]
# **H3** Take a moment to reflect on what your data analysis says about your PDF files. Jot down some reflections in the cell below.

# %% [markdown]
# My analysis tells me...I probably should have found something more interesting than medical journals on the same topic. (I am more interested in the api calls part of this class than the text analysis, albeit this is SUPER COOL). I am a bit of a novice and have been having to have chatgpt explain literally every cell to me, but things are starting to click a bit.

# %% [markdown]
# # All Done!
#
# Congrats you are finished with this week's work. Don't forget to click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work. Save this as a PDF and upload it to the Library Juice Academy site.
